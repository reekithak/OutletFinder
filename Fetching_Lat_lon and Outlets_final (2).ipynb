# %% [markdown]
# # finding Data points

# %%
import pandas as pd 
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline
import gmplot

# %%
main_lat1 = [13.260468,13.222991,13.217901,12.962429,13.051729,13.134076,13.191146,13.151139,13.142751,13.213578,13.206123,13.064444,12.941341]
main_lon1 = [80.294802,80.257521,80.195653,80.109385,80.083951,80.124658,80.153937,80.138858,80.296786,80.199158,80.2795557,80.135029,80.106315]
main_lat2 = [12.837568,12.860506,12.885142,12.943746,13.010036,13.072369,13.155816,12.841509,12.930147,12.844308,13.116652,13.032742,12.919885]
main_lon2 = [80.244451,80.195653,80.129427,80.258393,80.271829,80.288333,80.303396,80.242229,80.100572,80.227872,80.119715,80.273815,80.239358]

# %%
new_im = plt.imread(r"C:\Users\samen\new_image.png")

# %%
plt.imshow(new_im)

# %%
i=0
coord_df = pd.DataFrame()
lat_total =[main_lat1[i],main_lat2[i]]
lon_total = [main_lon1[i],main_lon2[i]]

# %%
final_df = pd.DataFrame()

# %%
def mid_point(lat1,lon1,lat2,lon2):
    lat3=lon3=0
    lat1 = math.radians(lat1)
    lon1 = math.radians(lon1)
    lat2 = math.radians(lat2)
    lon2 = math.radians(lon2)
    bx = math.cos(lat2) * math.cos(lon2 - lon1)
    by = math.cos(lat2) * math.sin(lon2 - lon1)
    lat3 = math.atan2(math.sin(lat1) + math.sin(lat2), \
           math.sqrt((math.cos(lat1) + bx) * (math.cos(lat1) \
           + bx) + by**2))
    lon3 = lon1 + math.atan2(by, math.cos(lat1) + bx)
    lat3 = round(math.degrees(lat3), 6)
    lon3 = round(math.degrees(lon3), 6)
    lat_total.append(lat3)
    lon_total.append(lon3)
    
    #return lat3,lon3

# %%
for i in range(len(main_lat1)):
    mid_point(main_lat1[i],main_lon1[i],main_lat2[i],main_lon2[i]) #lat 3 is saved as 0
    mid_point(main_lat1[i],main_lon1[i],lat_total[0],lon_total[0]) #lat 4 is saved as 1
    mid_point(lat_total[0],lon_total[0],main_lat2[i],main_lon2[i]) #lat5 is saved as  2
    mid_point(main_lat1[i],main_lon1[i],lat_total[1],lon_total[1]) #lat6 is saved as 3
    mid_point(lat_total[0],lon_total[0],lat_total[2],lon_total[2]) #lat8 is saved as 4
    mid_point(lat_total[1],lon_total[1],lat_total[0],lon_total[0]) #lat7 is saved as 5
    mid_point(lat_total[2],lon_total[2],main_lat2[i],main_lon2[i]) #lat9 is saved as 6
    mid_point(main_lat1[i],main_lon1[i],lat_total[2],lon_total[2]) #lat10 is saved as 7
    mid_point(lat_total[1],lon_total[1],main_lat2[i],main_lon2[i]) #lat11 is saved as 8
    mid_point(lat_total[0],lon_total[0],lat_total[1],lon_total[1]) #lat12 is saved as 9
    mid_point(lat_total[2],lon_total[2],main_lat1[i],main_lon1[i]) #lat13 is saved as 10
    mid_point(main_lat1[i],main_lon1[i],lat_total[6],lon_total[6])
    mid_point(lat_total[2],lon_total[2],lat_total[0],lon_total[0])
    mid_point(lat_total[2],lon_total[2],lat_total[9],lon_total[9])
    mid_point(main_lat1[i],main_lon1[i],lat_total[8],lon_total[8])
    mid_point(lat_total[2],lon_total[2],lat_total[7],lon_total[7])
    mid_point(lat_total[2],lon_total[2],lat_total[5],lon_total[5])
    mid_point(lat_total[8],lon_total[8],main_lat2[i],main_lon2[i])

# %%
final_df['Latitude']=lat_total
final_df['Longitude']=lon_total

# %%
final_df = final_df.drop_duplicates()

# %%
lat_total
# Out:
# [13.260468,
#  12.837568,
#  13.049019,
#  13.260468,
#  13.049019,
#  13.049019,
#  13.154744,
#  13.049019,
#  12.943294,
#  13.154744,
#  12.837568,
#  13.049019,
#  13.154744,
#  13.207606,
#  13.154744,
#  13.101882,
#  13.101882,
#  13.049019,
#  13.049019,
#  12.890431,
#  13.04175,
#  13.24173,
#  13.060492,
#  13.03028,
#  13.154744,
#  13.049019,
#  12.954765,
#  13.136005,
#  12.849038,
#  13.049019,
#  13.136005,
#  13.188868,
#  13.154744,
#  13.101882,
#  13.083143,
#  13.049019,
#  13.049019,
#  12.901902,
#  13.051524,
#  13.239189,
#  13.072818,
#  13.027736,
#  13.154744,
#  13.049019,
#  12.96709,
#  13.133463,
#  12.861361,
#  13.049019,
#  13.133463,
#  13.186326,
#  13.154744,
#  13.101882,
#  13.080599,
#  13.049019,
#  13.049019,
#  12.914226,
#  12.953098,
#  13.111465,
#  13.102108,
#  12.900007,
#  13.154744,
#  13.049019,
#  12.996383,
#  13.005736,
#  12.890657,
#  13.049019,
#  13.005736,
#  13.058601,
#  13.154744,
#  13.101882,
#  12.952872,
# ...

# %%
if(len(lat_total)==len(lon_total)):
    #final_df['Area']=['Ch'+str(x) for x in range(len(lat_total))]
    pass

# %%
BBox = ((final_df.Longitude.min(),final_df.Longitude.max(),final_df.Latitude.min(), final_df.Latitude.max()))
#https://www.openstreetmap.org/export#map=5/51.500/-0.100

# %%
BBox
# Out:
# (80.162518, 80.2991, 12.837568, 13.260468)

# %%
rng = np.random.RandomState(0)

# %%
colors = rng.rand(236) # raises with 18

# %%
sizes = 2200 * rng.rand(236)

# %%
plt.scatter(lon_total,lat_total,c=colors, s=sizes, alpha=0.3,
            cmap='viridis')
plt.colorbar()

# %%
final_df.shape
# Out:
# (128, 3)

# %%
final_df.to_csv(r"C:\Users\samen\maps api\final_df.csv",index=False)

# %% [markdown]
# # Finding Outlets

# %%
import pandas as pd
import requests
import json
import os
from pandas.io.json import json_normalize 
from datetime import datetime
from time import time
from time import sleep
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
import simplejson as json

# %%
os.chdir(r'C:\Users\samen\maps api\final_all')

outlets_failed = []
fromaddr = "pibarcodesean"
toaddr = 'youremail'
data = pd.read_csv(r"C:\Users\samen\Haversine_distance.csv")
data1 = data
json_data = pd.DataFrame()
#ls = ['beauty_salon','hair_care','spa'] 

date = str(datetime.now())
t0 = time()

# %%
f = open(r"C:\Users\samen\maps api\establishment types.txt",'r')
x = f.readlines()

# %%
ls= []
number = 20

# %%
for iter_ in range(number):
    ls_ = x[iter_]
    try:
        ls_=ls_.replace('\n','')
    except:
        pass
    ls.append(ls_)

# %%
ls = ['accounting','aquarium','airport','art_gallery','atm','bakery', 'bank','bar','beauty_salon','bus_station','cafe','campground','car_dealer']

# %%
data1
columns = ['Latitude','Longitude']

# %%
data1 = (data1.drop(columns,axis=1).join(data1[columns].apply(pd.to_numeric,errors = 'coerce')))
data1.dropna(inplace=True)

# %%
data1['Area'] = ['Ch'+str(x) for x in range(data1.shape[0])]

# %%
df1 = pd.DataFrame()
outlets_failed = []

# %%
data1.shape
# Out:
# (415294, 3)

# %%
import os
try:
    os.remove('cluster_first_20.csv')
except:
    pass

# %%
for l in ls:
    print (l)
    
    for i in range(len(data1)):
        elist = []
        clust_no = data1.iloc[i,0]
        addr = data1.iloc[i,1]
        adde = data1.iloc[i,2]
        url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location='
        url += str(addr)
        url += ','
        url += str(adde)
        url += '&radius=2500&types=%s&key=YOURAPIKEY'%l
        try:
            t1 = time()
            response = requests.get(url)
            t2 = time()
            t = t2-t1
            print ('Time taken for Outlet ' + str(clust_no) + ' is: ' + str(t))           
            json_data=json.loads(response.text)
            filename = 'Outlet_' + str(clust_no) + '_' + str(l) + '.json'
            with open(filename, 'wb') as file:
                file.write(response.content)
            elist.append(response.content)
            while len(json_data)>3:
                npt = json_data['next_page_token']
                sleep(3)
                url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location='
                url += str(addr)
                url += ','
                url += str(adde)
                url += '&radius=2500&types=%s&key=YOURAPIKEY'%l
                url += '&pagetoken='
                url += str(npt)
                t3 = time()
                response = requests.get(url)
                t4 = time()
                t5 = t4-t3
                print ('Time taken for Outlet ' + str(clust_no) + ' is: ' + str(t5))            
                json_data=json.loads(response.text)
                with open(filename, 'a') as file:
                    file.write(response.content)
                elist.append(response.content)
                
        except Exception as e:
            print ('OUTLET ' + str(clust_no) + ' ' + str(l) + ' FAILED')
            print (e)
            outlets_failed.append(i)
            msg = MIMEMultipart()
            msg['From'] = fromaddr
            msg['To'] = toaddr
            msg['Subject'] = '[Nearbysearch] Outlet ' + str(clust_no) + ' Failed'
            body = '[Nearbysearch] Outlet ' + str(clust_no) + ' Failed'
            msg.attach(MIMEText(body, 'plain'))
            try:
                server = smtplib.SMTP('smtp.gmail.com', 587)
                server.starttls()
                server.login(fromaddr, "9645748121aA#")
                text = msg.as_string()
                server.sendmail(fromaddr, toaddr, text)
                server.quit()
            except Exception:
                pass
            continue
        json_data = json.loads(json.dumps(elist))
        json_data = [s.encode('utf-8') for s in json_data]
        for v in json_data:
            d = json.loads(v)
            temp_df = json_normalize(d['results'])
            temp_df['input_lat'] = addr
            temp_df['input_long'] = adde
            temp_df['cluster_no'] = clust_no
            temp_df['query'] = url
            temp_df['input_type'] = l
            temp_df['date'] = date
            df1 = df1.append(temp_df)

    for i in outlets_failed:
        elist = []
        url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location='
        url += str(addr)
        url += ','
        url += str(adde)
        url += '&radius=2500&types=%s&key=YOURAPIKEY'%l
        try:
            t1 = time()
            response = requests.get(url)
            t2 = time()
            t = t2-t1
            print ('Time taken for Outlet ' + str(clust_no) + ' is: ' + str(t))                        
            json_data=json.loads(response.text)
            filename = 'Outlet_' + str(clust_no) + '_'  + str(l) + '.json'
            with open(filename, 'wb') as file:
                file.write(response.content)
            elist.append(response.content)
            while len(json_data)>3:
                npt = json_data['next_page_token']
                sleep(2)
                url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location='
                url += str(addr)
                url += ','
                url += str(adde)
                url += '&radius=2500&types=%s&key=YOURAPIKEY'%l
                url += '&pagetoken='
                url += str(npt)
                t3 = time()
                response = requests.get(url)
                t4 = time()
                t5 = t4-t3                
                json_data=json.loads(response.text)
                with open(filename, 'a') as file:
                    file.write(response.content)
                elist.append(response.content)
                
        except Exception as e:
            print ('OUTLET ' + str(clust_no) + ' ' + str(l) + ' FAILED') 
            print (e)
            outlets_failed.append(i)
            msg = MIMEMultipart()
            msg['From'] = fromaddr
            msg['To'] = toaddr
            msg['Subject'] = '[Nearbysearch] Outlet ' + str(clust_no) + ' Failed'
            body = '[Nearbysearch] Outlet ' + str(clust_no) + ' Failed'
            msg.attach(MIMEText(body, 'plain'))
            try:
                server = smtplib.SMTP('smtp.gmail.com', 587)
                server.starttls()
                server.login(fromaddr, "Welcome@123")
                text = msg.as_string()
                server.sendmail(fromaddr, toaddr, text)
                server.quit()
            except Exception:
                pass
            continue
        json_data = json.loads(json.dumps(elist))
        json_data = [s.encode('utf-8') for s in json_data]
        for v in json_data:
            d = json.loads(v)
            temp_df = json_normalize(d['results'])
            temp_df['input_lat'] = addr
            temp_df['input_long'] = adde
            temp_df['cluster_no'] = clust_no
            temp_df['query'] = url
            temp_df['input_type'] = l
            temp_df['date'] = date
            df1 = df1.append(temp_df)
            outlets_failed = []
    
df1.to_csv('cluster_first_20.csv',index = False, encoding = 'utf-8')

t6 = time()
print ("Time taken", round(t6-t0,3), "s")
tim_taken= round(t6-t0,3)
# Out:
# accounting
# c:\users\samen\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:69: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# Time taken for Outlet 28.224696927405 is: 0.4886958599090576
# Time taken for Outlet 28.241060542089 is: 0.27429938316345215
# Time taken for Outlet 28.242558038463997 is: 0.2764005661010742
# Time taken for Outlet 28.277729144518 is: 0.25136566162109375
# Time taken for Outlet 28.284699917501 is: 0.25307440757751465
# Time taken for Outlet 28.242508094943 is: 0.2478327751159668
# Time taken for Outlet 28.277245031670002 is: 0.31143951416015625
# Time taken for Outlet 28.223793192362 is: 0.23609328269958496
# Time taken for Outlet 28.242567328511 is: 0.26480531692504883
# Time taken for Outlet 28.276561237141 is: 0.25754594802856445
# Time taken for Outlet 28.284742042865 is: 0.2613043785095215
# Time taken for Outlet 28.2413348177 is: 0.32489585876464844
# ...

# %%
print(tim_taken)

# %%
df1
# Out:
#     input_lat  input_long cluster_no  \
# 0   13.154744   80.282198         Ch
# 1   13.154744   80.282198         Ch
# 2   13.154744   80.282198         Ch
# 3   13.154744   80.282198         Ch
# 4   13.154744   80.282198         Ch
# ..        ...         ...        ...
# 7   12.931590   80.248190         Ch
# 8   12.931590   80.248190         Ch
# 9   12.931590   80.248190         Ch
# 10  12.931590   80.248190         Ch
# 11  12.931590   80.248190         Ch
#
#                                                 query  input_type  \
# 0   https://maps.googleapis.com/maps/api/place/nea...  accounting
# 1   https://maps.googleapis.com/maps/api/place/nea...  accounting
# 2   https://maps.googleapis.com/maps/api/place/nea...  accounting
# 3   https://maps.googleapis.com/maps/api/place/nea...  accounting
# 4   https://maps.googleapis.com/maps/api/place/nea...  accounting
# ..                                                ...         ...
# ...

# %%
try:
    df1.drop_duplicates()
except:
    df1.iloc[df1.astype(str).drop_duplicates().index]

# %%
df1.to_csv("final_file_all_fetched.csv")

# %%
df1
# Out:
#     input_lat  input_long cluster_no  \
# 0   13.154744   80.282198         Ch
# 1   13.154744   80.282198         Ch
# 2   13.154744   80.282198         Ch
# 3   13.154744   80.282198         Ch
# 4   13.154744   80.282198         Ch
# ..        ...         ...        ...
# 7   12.931590   80.248190         Ch
# 8   12.931590   80.248190         Ch
# 9   12.931590   80.248190         Ch
# 10  12.931590   80.248190         Ch
# 11  12.931590   80.248190         Ch
#
#                                                 query  input_type  \
# 0   https://maps.googleapis.com/maps/api/place/nea...  accounting
# 1   https://maps.googleapis.com/maps/api/place/nea...  accounting
# 2   https://maps.googleapis.com/maps/api/place/nea...  accounting
# 3   https://maps.googleapis.com/maps/api/place/nea...  accounting
# 4   https://maps.googleapis.com/maps/api/place/nea...  accounting
# ..                                                ...         ...
# ...
